# %%
# for questions, contact karenmei@ucsd.edu

#Goal: To evaluate the custom hierarchy (Metric #2)

#Metric 2: To create a pipeline for testing for how well the custom ontology maps onto reference ontology using DDOT 
#How well does the model capture the known structure of the reference ontology? (evaluated by alignment to the Gene Ontology, i.e. how many GO terms significantly overlap gene modules in your model?)

#	   code for customizing ontologies: DDOT: https://github.com/michaelkyu/ddot/blob/master/examples/Tutorial.ipynb

import sys
sys.path.append('C:\\Users\\Anubhav\\Documents\\GitHub\\ddot')

import pandas as pd
import networkx as nx
import numpy as np
import os
import ddot
from ddot import Ontology
import csv
import scipy.stats as ss
from scipy.stats import hypergeom
from statsmodels.sandbox.stats.multicomp import multipletests

os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
#Create dictionary of all the term_names and description (in this example: GO)
#i.e. example in this dictionary: key is 'GO:0005694'; value: 'chromosome'
#input: Term is a GO term; for example: 'GO:0005694'

def Find_GO_Term_Desc(Term):
	with open('goID_2_name.tab', 'r') as f:
		GO_terms=[r for r in csv.reader(f, delimiter='\t')]
	term=[]
	desc=[]
	for i in range(len(GO_terms)):
		term.append(GO_terms[i][0])
		desc.append(GO_terms[i][1])
	dictionary=dict(list(zip(term, desc)))
	description=dictionary[Term]
	return description


#Generate custom ontology file
def Generate_Ontology_File(Term, file_name):
	ndex_server ='http://public.ndexbio.org' 
	go_human = Ontology.from_ndex('http://public.ndexbio.org/v2/network/16565851-4bfc-11e9-9f06-0ac135e8bacf')
	ont= go_human.focus(Term)
	ont.to_table(file_name)
	return ont

#Convert the custom ontology into the desired descriptions and gene names (in this example: GO descriptions and gene IDs)
#the input to this function is ont, which is the output of Generate_Ontology_File
def Find_GO_Focus_GeneDict(ont):
	ont = ont.propagate(direction='forward', gene_term=True, term_term=False)
	terms_to_genes=ont.term_2_gene
	GO_Desc=[]
	gene_names=[]
	for key in terms_to_genes:
		term_name=key
		GO_Desc.append(term_name)
		genes_in_terms=terms_to_genes[key]
		genes_list=[]
		for item in genes_in_terms:
			gene_name=ont.genes[item]
			genes_list.append(gene_name)
		gene_names.append(genes_list)
	GO_term_gene=list(zip(GO_Desc, gene_names))
	GO_dict=dict(GO_term_gene)
	return GO_dict

#Find the enriched terms within the custom ontology
#function input: ont (output of Generate_Ontology_File)
#               syn_ont (output of Find_GO_Focus_GeneDict)
#               test_gene_list (list of genes to be tested)
def Find_Enrichment(ont, syn_ont, test_gene_list):
	num_ont_genes=len(ont.genes)
	num_intersect_test_ont=len(set(ont.genes)&set(test_gene_list))
	overlap=[]
	for key in syn_ont:
		pair=[]
		ont_gene_list=syn_ont[key]
		size_ont_genes=len(ont_gene_list)
		overlap_num=len(list(set(ont_gene_list)&set(test_gene_list)))
		pair.append(key)
		pair.append(overlap_num)
		pair.append(size_ont_genes)
		overlap.append(pair)
	p_values=[]
	for item in overlap:
		intersect_termgenes_testgenes=item[1]
		num_term_genes=item[2]
		p=hypergeom.sf(intersect_termgenes_testgenes-1, num_ont_genes,num_intersect_test_ont, num_term_genes)
		p_values.append(p)
	p_adj=multipletests(p_values,method='fdr_bh')
	boolean_p=p_adj[0]
	idx_true=[i for i, e in enumerate(boolean_p) if e != False]
	p_adj=p_adj[1]
	min_p=min(p_adj)
	idx_min_p=[i for i, e in enumerate(p_adj) if e == min_p]
	most_enriched_terms=[]
	for item in idx_min_p:
		term_padj_pair=[]
		enriched=overlap[item][0]
		GO_term_padj=p_adj[item]
		term_padj_pair.append(enriched)
		term_padj_pair.append(GO_term_padj)
		most_enriched_terms.append(term_padj_pair)
	true_terms=[]
	for item in idx_true:
		true_pair=[]
		true_term=overlap[item][0]
		true_padj=p_adj[item]
		true_pair.append(true_term)
		true_pair.append(true_padj)
		true_terms.append(true_pair)
	#print ('terms above threshold:', true_terms)
	return true_terms

#Find the number of enriched modules
#function input: ont1, ont2
#ont1 (ontology 1); ont2 (ontology 2)
def Num_Enriched_Modules(ont1, ont2):
	chr_ont=Find_GO_Focus_GeneDict(ont1)
	print (chr_ont)
	test_ont=Find_GO_Focus_GeneDict(ont2)
	print (test_ont)
	enriched_modules=[]
	for key in test_ont:
		test_gene_list=test_ont[key]
		if len(test_gene_list)!=0:
			enriched_terms=Find_Enrichment(ont1, chr_ont, test_gene_list)
			enriched_modules.append(enriched_terms)
		else:
			continue
	enriched_modules = [x for x in enriched_modules if x != []]
	enriched_modules = [item for sublist in enriched_modules for item in sublist]
	enriched_term_names=[]
	for item in enriched_modules:
		enriched_term_name=item[0]
		enriched_term_names.append(enriched_term_name)
	unique_enriched_term_names=set(enriched_term_names)
	#print (unique_enriched_term_names)
	print ('Num of Enriched Modules', len(unique_enriched_term_names))
	return

# %%
#Loading clixo data
final_ont_fn = 'finalontology3.txt'

#our_ont = 'string_synapse_interactions_combined_score.clixo_alpha0.2_beta0.7.txt'
our_ont = '../../output/run_clixo/option2/'
our_ont += 'string_synapse_interactions_combined_score.clixo_alpha0.22_beta0.72.txt'


clixo_ont = pd.read_table(our_ont, dtype=str, comment='#', header=None, 
                          names=['Parent', 'Child', 'EdgeType', 'drop'])
clixo_ont.drop('drop', axis=1, inplace=True)
clixo_ont.loc[:, 'EdgeType'] = clixo_ont.EdgeType.str.replace('gene', 'Gene-Term').replace('default', 'Child-Parent')


clixo_ont.to_csv(final_ont_fn, header=True, index=False, sep='\t', mode='a')

# %%
#Generate custom ontology 1 from Chromatin branch from human GO
#ontology_file=Generate_Ontology_File('GO:0000785', 'ont1.txt')
ont1 = Ontology.from_table(final_ont_fn)
#print (ont1)

#Generate custom ontology 2 from Chromosome branch from human GO
#ont2_file=Generate_Ontology_File('GO:0005694', 'ont2.txt')
ont2 = Ontology.from_table('synapse.txt')
#print (ont2)

Num_Enriched_Modules(ont1, ont2)
# Out:
# {'1373': ['AAK1', 'SYNJ1', 'SYNJ2', 'PACSIN1', 'PACSIN2', 'EPS15', 'HIP1', 'HIP1R', 'SLC18A3', 'SYT1', 'RAB5A', 'RAB5B', 'RAB5C', 'SYT11', 'ACTR2', 'SYT2', 'SLC2A8', 'HSPA8', 'FCHO2', 'SYT8', 'SYT9', 'CTTN', 'PICALM', 'AMPH', 'AP2B1', 'ITSN1', 'UBA52', 'GAK', 'DNAJC6', 'DNM1', 'DNM2', 'DNM3', 'CHRM2', 'STON2', 'ARPC2', 'ARRB1', 'ARRB2', 'VAMP2', 'VAMP3', 'VAMP4', 'VAMP7', 'EGFR', 'CLTA', 'CLTB', 'WNT5A', 'BIN1', 'SH3GL1', 'SH3GL2', 'SH3GL3', 'SH3KBP1'], '1392': ['AAK1', 'ABCC8', 'ABHD17A', 'ABHD17B', 'ABHD17C', 'ABHD6', 'ABI1', 'ABI2', 'ABL1', 'ABLIM3', 'ABR', 'ACAN', 'ACHE', 'ACTB', 'ACTBL2', 'ACTC1', 'ACTN1', 'ACTN2', 'ACTR2', 'ADAM10', 'ADAM19', 'ADAM22', 'ADAM23', 'ADCY1', 'ADCY8', 'ADCYAP1', 'ADD1', 'ADD2', 'ADD3', 'ADORA1', 'ADORA2A', 'ADORA2B', 'ADRA1A', 'ADRA2C', 'ADRB1', 'AGER', 'AGRN', 'AKAP12', 'AKAP5', 'AKAP7', 'AKAP9', 'AKR1A1', 'AKT1', 'ALCAM', 'ALS2', 'AMPH', 'ANK1', 'ANK2', 'ANK3', 'ANKS1B', 'ANXA1', 'AP1S1', 'AP2B1', 'AP3B1', 'AP3D1', 'APBA1', 'APBA2', 'APBA3', 'APBB1', 'APC2', 'APH1A', 'APLP1', 'APOE', 'APOL2', 'APOL4', 'APP', 'ARC', 'ARF1', 'ARF4', 'ARF6', 'ARFGAP1', 'ARFGEF2', 'ARHGAP22', 'ARHGAP32', 'ARHGAP33', 'ARHGAP39', 'ARHGAP44', 'ARHGEF15', 'ARHGEF2', 'ARHGEF28', 'ARHGEF7', 'ARHGEF9', 'ARL8A', 'ARL8B', 'ARPC2', 'ARPC5L', 'ARR3', 'ARRB1', 'ARRB2', 'ASAP1', 'ASCC1', 'ASIC1', 'ASIC2', 'ATAD1', 'ATCAY', 'ATP1A1', 'ATP1A2', 'ATP1A3', 'ATP2A2', 'ATP2B1', 'ATP2B2', 'ATP2B3', 'ATP2B4', 'ATP6V0D1', 'ATP6V1B1', 'BAALC', 'BACE1', 'BAI3', 'BAIAP3', 'BCAN', 'BCL11A', 'BCL2L1', 'BCR', 'BDNF', 'BEGAIN', 'BIN1', 'BLOC1S6', 'BLVRB', 'BMPR2', 'BNIP3', 'BRAF', 'BRSK1', 'BSN', 'C11orf85', 'C14orf39', 'C15orf43', 'C16orf70', 'C1QB', 'C1QBP', 'C1QC', 'C1QL1', 'C1QL2', 'C1QL3', 'C1QL4', 'C4A', 'C4B', 'CABP1', 'CABP4', 'CACNA1C', 'CACNA1D', 'CACNG2', 'CACNG3', 'CACNG4', 'CACNG5', 'CACNG7', 'CACNG8', 'CAD', 'CADM1', 'CADM2', 'CADM3', 'CADPS', 'CADPS2', 'CALB1', 'CALB2', 'CALCA', 'CALM1', 'CALM2', 'CALM3', 'CALY', 'CAMK2A', 'CAMK2B', 'CAMK2G', 'CAMK2N1', 'CAMK4', 'CAMKV', 'CANX', 'CAP2', 'CAPRIN1', 'CAPRIN2', 'CASK', 'CASR', 'CAV3', 'CBLN1', 'CBLN2', 'CBLN3', 'CBLN4', 'CC2D1A', 'CCDC36', 'CCDC79', 'CCDC88A', 'CCK', 'CD3E', 'CD47', 'CD6', 'CDC20', 'CDC42', 'CDC42SE1', 'CDC42SE2', 'CDH1', 'CDH11', 'CDH13', 'CDH15', 'CDH2', 'CDH8', 'CDH9', 'CDK16', 'CDK5', 'CDK5R1', 'CDKL5', 'CEL', 'CEP112', 'CHAT', 'CHD8', 'CHI3L1', 'CHL1', 'CHMP2B', 'CHRFAM7A', 'CHRM1', 'CHRM2', 'CHRM3', 'CHRM4', 'CHRM5', 'CHRNA1', 'CHRNA10', 'CHRNA2', 'CHRNA3', 'CHRNA4', 'CHRNA5', 'CHRNA7', 'CHRNA9', 'CHRNB1', 'CHRNB2', 'CHRNB3', 'CHRNB4', 'CHRND', 'CHRNE', 'CHRNG', 'CHST10', 'CIB2', 'CLCN3', 'CLN3', 'CLRN1', 'CLSTN1', 'CLSTN2', 'CLSTN3', 'CLTA', 'CLTB', 'CLU', 'CNGB1', 'CNIH2', 'CNIH3', 'CNKSR2', 'CNN3', 'CNR1', 'CNTN1', 'CNTN2', 'CNTN4', 'CNTN5', 'CNTN6', 'CNTNAP1', 'CNTNAP2', 'CNTNAP4', 'COL13A1', 'COL4A5', 'COLQ', 'COMT', 'COPS4', 'COPS5', 'CORO1A', 'CORO1C', 'CPE', 'CPEB1', 'CPEB2', 'CPEB3', 'CPEB4', 'CPLX1', 'CPLX2', 'CPLX3', 'CPLX4', 'CPT1C', 'CRHBP', 'CRHR2', 'CRIPT', 'CRKL', 'CRTC1', 'CRYAB', 'CSNK1G1', 'CSNK1G2', 'CSNK1G3', 'CSPG5', 'CTBP1', 'CTBP2', 'CTNNA1', 'CTNNA2', 'CTNNB1', 'CTNND1', 'CTNND2', 'CTTN', 'CTTNBP2', 'CUBN', 'CYFIP1', 'CYFIP2', 'CYP46A1', 'DAB1', 'DACT1', 'DAGLA', 'DAGLB', 'DAOA', 'DARS', 'DBN1', 'DBNL', 'DCC', 'DCLK1', 'DCTN2', 'DDC', 'DDN', 'DENND1A', 'DES', 'DGKB', 'DGKE', 'DGKI', 'DGKQ', 'DGKZ', 'DISC1', 'DLG1', 'DLG2', 'DLG3', 'DLG4', 'DLG5', 'DLGAP1', 'DLGAP2', 'DLGAP3', 'DLGAP4', 'DMD', 'DMTN', 'DMXL2', 'DNAJA3', 'DNAJC5', 'DNAJC6', 'DNM1', 'DNM1L', 'DNM2', 'DNM3', 'DNMBP', 'DOC2A', 'DOC2B', 'DOCK10', 'DOK7', 'DPYSL3', 'DRD1', 'DRD2', 'DRD3', 'DRD4', 'DRD5', 'DROSHA', 'DRP2', 'DSCAML1', 'DTNA', 'DTNBP1', 'DVL1', 'DYNLL2', 'DYSF', 'EEA1', 'EEF1A2', 'EEF2', 'EEF2K', 'EFNA2', 'EFNA5', 'EFNB1', 'EFNB2', 'EFNB3', 'EGFLAM', 'EGFR', 'EGLN1', 'EIF2B1', 'EIF2B2', 'EIF2B3', 'EIF2B4', 'EIF2B5', 'EIF2S1', 'EIF3A', 'EIF3B', 'EIF4A3', 'EIF4E', 'EIF4EBP1', 'EIF4EBP2', 'ELAVL1', 'ELFN1', 'ELK1', 'EMB', 'ENAH', 'ENSG00000204176', 'ENSG000002 ...
# {'GO:0043195': ['AAK1', 'CABP4', 'ILK', 'POLG', 'CYFIP1', 'CAD', 'CALCA', 'ADCYAP1', 'KCNC2', 'ADORA1', 'NMU', 'GHRH', 'CCK', 'PRSS12', 'SYNJ1', 'SYP', 'AP1S1', 'SYT11', 'AP3D1', 'NTRK2', 'PTPRN2', 'NTSR1', 'TBC1D24', 'TH', 'GRIK2', 'GRIK3', 'OPHN1', 'GRIK5', 'GRIN1', 'OXT', 'SLC18A1', 'SLC18A2', 'P2RX3', 'P2RX4', 'RAB3A', 'SLC18A3', 'LRRK2', 'TNN', 'RAB5A', 'CNGB1', 'UNC13A', 'UNC13B', 'UNC13C', 'MICAL1', 'USH2A', 'SNCA', 'BLVRB', 'HSPA8', 'CPLX1', 'CPLX2', 'CPLX3', 'CPLX4'], 'GO:0030672': ['ABCC8', 'ICA1', 'AC099811.2', 'STX10', 'STX12', 'STX16', 'STX1A', 'STX6', 'SV2A', 'SV2B', 'SV2C', 'SVOP', 'SYN1', 'SYN2', 'SYN3', 'PRRT2', 'SYNGR2', 'DMXL2', 'SYNGR3', 'SYNGR4', 'SYNGR1', 'DNAJC5', 'AMPH', 'DNM1L', 'SYNPR', 'SYP', 'SYPL1', 'DOC2A', 'SYT1', 'SYT11', 'SYT12', 'SYT2', 'DRD2', 'SYT5', 'SYT6', 'LAMP5', 'SYT7', 'SYT8', 'SYT4', 'LAMP1', 'DTNBP1', 'PTPRN2', 'PTPRS', 'SYT9', 'RAB11B', 'RAB26', 'TMEM163', 'RAB27B', 'RAB35', 'RAB3A', 'RAB3B', 'RAB3C', 'LRRK2', 'TPRG1L', 'RAB4A', 'RAB5A', 'RAB5B', 'RAB5C', 'UNC13A', 'UNC13B', 'UNC13C', 'ATP6V1B1', 'MCTP1', 'MCTP2', 'BCL2L1', 'VAMP1', 'VAMP2', 'VAMP3', 'VAMP4', 'VAMP7', 'BSN', 'RPH3A', 'C16orf70', 'WFS1', 'GABRA2', 'ZNRF1', 'CALM1', 'CALM2', 'CALM3', 'SCAMP1', 'SCAMP5', 'GAD2', 'CBARP', 'SEMA4C', 'SEPT8', 'SGTA', 'SH3GL2', 'SLC17A5', 'SLC17A6', 'SLC17A7', 'OPRD1', 'SLC18A1', 'SLC18A2', 'OTOF', 'OPRK1', 'SLC17A8', 'SLC30A3', 'SLC32A1', 'CLTA', 'CLTB', 'SLC6A17', 'SLC6A9', 'SLC9B2', 'SNAP47', 'SNAPIN', 'SNCA', 'PI4K2A', 'CPLX3'], 'GO:0043197': ['ABHD17A', 'ABHD17B', 'ABHD17C', 'IGF2BP1', 'ABI2', 'SRGAP2', 'SRI', 'STRN', 'STRN4', 'ACTN2', 'ITGB1', 'ADAM10', 'ITPKA', 'STX4', 'KCNA4', 'ADGRB1', 'ADORA1', 'KCND2', 'KCNJ2', 'SYNDIG1', 'AKAP5', 'KCNN2', 'ALS2', 'SYNPO', 'ANKS1B', 'SYT11', 'APBA1', 'APBA2', 'APBA3', 'APBB1', 'LAMA2', 'APP', 'ARC', 'TENM2', 'ARF4', 'LPAR1', 'TIAM1', 'ARFGEF2', 'ARHGAP32', 'ARHGAP33', 'ARHGAP44', 'LRRC4', 'ARRB1', 'ARRB2', 'ASAP1', 'LZTS1', 'ASIC2', 'ATP1A2', 'MAP1B', 'MAPT', 'USP50', 'USP8', 'MOB4', 'MPP2', 'MT3', 'MTMR2', 'MYH10', 'MYL7', 'ZMYND8', 'CALB1', 'ZNF804A', 'NEDD4', 'NEURL1', 'CAMK2A', 'NLGN1', 'CANX', 'NOS1', 'CD3E', 'CDC42', 'NR1D1', 'NRGN', 'CDK5R1', 'NTRK2', 'NTSR1', 'OPHN1', 'OPRD1', 'OPRM1', 'P2RX3', 'P2RX4', 'P2RX6', 'CLSTN1', 'CNIH2', 'PALMD', 'CNN3', 'PDE4B', 'PDLIM4', 'COMT', 'CPEB4', 'CRIPT', 'CRYAB', 'CTNND1', 'CTTN', 'CTTNBP2', 'CYFIP1', 'PPP1CA', 'PPP1CC', 'PPP1R1B', 'PPP1R9A', 'PPP1R9B', 'PPP3CA', 'DGKI', 'PRKACA', 'PRKAR2B', 'DLG4', 'PRRT2', 'PSD', 'DNAJB1', 'DNM1', 'DNM2', 'PSMC2', 'DNM3', 'DOCK10', 'PTEN', 'PTK2', 'DRD1', 'DRD2', 'PTK2B', 'PTPRO', 'DTNBP1', 'DVL1', 'EEF2K', 'RAB8A', 'RAC1', 'EPHA4', 'RGS10', 'RGS14', 'RHOA', 'FARP1', 'FBXO2', 'FCGR2B', 'FMR1', 'FRMPD4', 'FUS', 'FXR1', 'FXR2', 'SEPT11', 'GIPC1', 'SEZ6', 'SHANK1', 'SHANK2', 'SHANK3', 'GPER1', 'GPM6A', 'GRIA1', 'GRIA2', 'GRIA4', 'SIPA1L1', 'GRID2', 'GRIN1', 'GRM3', 'SLC8A1', 'SLC8A2', 'SLC8A3', 'HIP1R', 'HOMER1', 'HPCA'], 'GO:0099031': ['ABHD17A', 'ABHD17B', 'RGS7BP'], 'GO:0099033': ['ABHD17A', 'ABHD17B'], 'GO:0098978': ['ABHD17A', 'ABHD17B', 'ABHD17C', 'ABHD6', 'ABLIM3', 'ABR', 'ACAN', 'ACTB', 'ACTBL2', 'ACTC1', 'ACTN1', 'ACTN2', 'ADAM10', 'ADAM22', 'ADAM23', 'ADCY1', 'ADCY8', 'ADGRA1', 'ADGRL3', 'ADORA2A', 'ADORA2B', 'ADRA1A', 'ADRA2C', 'AKAP9', 'AP2B1', 'AP3D1', 'APBA1', 'APOE', 'ARC', 'ARF1', 'ARF4', 'ARF6', 'ARHGAP22', 'ARHGAP39', 'ARHGAP44', 'ARHGEF2', 'ARPC2', 'ARPC5L', 'ATAD1', 'ATP2B1', 'ATP2B2', 'ATP2B3', 'ATP2B4', 'BCAN', 'BCR', 'BSN', 'C1QBP', 'CACNG2', 'CACNG3', 'CACNG4', 'CACNG5', 'CACNG7', 'CADPS2', 'CALB1', 'CALY', 'CAMK1', 'CAMK4', 'CAMKV', 'CANX', 'CBLN1', 'CBLN2', 'CDH1', 'CDH10', 'CDH11', 'CDH8', 'CDK5', 'CDKL5', 'CHMP2B', 'CHRM1', 'CHRM2', 'CHRM3', 'CLSTN1', 'CLSTN2', 'CLSTN3', 'CNIH2', 'CNKSR2', 'CNR1', 'CORO1A', 'CPLX1', 'CPLX2', 'CPT1C', 'CRTC1', 'CSPG5', 'CTBP1', 'CTBP2', 'CTNND1', 'CTTNBP2', 'DAG1', 'DBN1', 'DGKB', 'DGKE', 'DGKI', 'DGKQ', 'DGKZ', 'DLG1', 'DLG2', 'DLG3', 'DLGAP3', 'DLGAP4', 'DNAJB1', 'DNM1', 'DNM2', 'DNM3', 'DRD1', 'DRD2', 'DR ...
# Num of Enriched Modules 63

# %%
print(ont1)
# Out:
# 1283 genes, 110 terms, 3555 gene-term relations, 109 term-term relations
# node_attributes: []
# edge_attributes: []
